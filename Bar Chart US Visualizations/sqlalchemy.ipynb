# %%
# Pandas
import pandas as pd
from sqlite3 import connect

# SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# %%
# declare the connection string specifying
# the host name database name use name
# and password
conn_string = "host='localhost' dbname='covid_vaccine'\
user='postgres' password='Nhy3035!'"
 
# use connect function to establish the connection
conn = psycopg2.connect(conn_string)

# %%
# Query All Records in the the Database
data = pd.read_sql('select * from vaccine2', conn)

# %%
# Preview the Data
data.head()
# Out:
#     id        date location  total_vaccinations  \
# 0  357  2022-01-04  Alabama           5678299.0
# 1  358  2022-01-05  Alabama           5681793.0
# 2  359  2022-01-06  Alabama           5695747.0
# 3  360  2022-01-07  Alabama           5710373.0
# 4  361  2022-01-08  Alabama           5723382.0
#
#    total_vaccinations_per_hundred  total_distributed  distributed_per_hundred  \
# 0                          115.81          8027420.0                   163.72
# 1                          115.88          8071240.0                   164.61
# 2                          116.16          8391130.0                   171.14
# 3                          116.46          8391130.0                   171.14
# 4                          116.73          8498480.0                   173.33
#
#    people_vaccinated  people_vaccinated_per_hundred  people_fully_vaccinated  \
# 0          2884819.0                          58.84                2345599.0
# 1          2886070.0                          58.86                2346404.0
# 2          2890246.0                          58.95                2349085.0
# 3          2894430.0                          59.03                2351731.0
# 4          2898115.0                          59.11                2354087.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations  \
# 0                                47.84             10478.0
# 1                                47.85             10508.0
# 2                                47.91             10216.0
# 3                                47.96             10761.0
# 4                                48.01             11075.0
#
#    daily_vaccinations_per_million  total_boosters  total_boosters_per_hundred
# 0                          2137.0        603124.0                       12.30
# 1                          2143.0        604626.0                       12.33
# 2                          2084.0        611874.0                       12.48
# 3                          2195.0        619829.0                       12.64
# 4                          2259.0        627028.0                       12.79
