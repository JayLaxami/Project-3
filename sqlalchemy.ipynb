# %%
# Pandas
import pandas as pd
from sqlite3 import connect

# SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# %%
# declare the connection string specifying
# the host name database name use name
# and password
conn_string = "host='localhost' dbname='covid_vaccine'\
user='postgres' password='Juhi@123'"
 
# use connect function to establish the connection
conn = psycopg2.connect(conn_string)

# %%
# Query All Records in the the Database
data = pd.read_sql('select * from vaccine2', conn)
# Out:
# c:\Users\juhis\anaconda3\New folder\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# Preview the Data
data.head()
# Out:
#    id    location  total_vaccinations  total_vaccinations_per_hundred  \
# 0   0     Alabama        1.112502e+09                        22689.35
# 1   1      Alaska        1.679931e+08                        22964.09
# 2   2     Arizona        2.115125e+09                        29059.03
# 3   3    Arkansas        7.558426e+08                        25046.07
# 4   4  California        6.478700e+09                        16396.68
#
#    total_distributed  distributed_per_hundred  people_vaccinated  \
# 0       1.722429e+09                 35128.81       5.467422e+08
# 1       2.287476e+08                 31269.16       7.541610e+07
# 2       2.606561e+09                 35810.74       9.321954e+08
# 3       1.108293e+09                 36725.08       3.602832e+08
# 4       7.887012e+09                 19960.91       2.823561e+09
#
#    people_vaccinated_per_hundred  people_fully_vaccinated  \
# 0                       11150.76             4.447364e+08
# 1                       10309.19             6.681710e+07
# 2                       12807.12             7.851515e+08
# 3                       11938.60             2.935521e+08
# 4                        7146.08             2.456102e+09
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations  \
# 0                              9070.42            773953.0
# 1                              9133.77            130727.0
# 2                             10786.90           2021814.0
# 3                              9727.33            553975.0
# 4                              6216.06           5670847.0
#
#    daily_vaccinations_per_million  total_boosters  total_boosters_per_hundred
# 0                        157841.0    1.504733e+08                     3068.85
# 1                        178700.0    3.187076e+07                     4356.62
# 2                        277772.0    4.563386e+08                     6269.52
# 3                        183564.0    1.222713e+08                     4051.69
# 4                        143520.0    1.379826e+09                     3492.17
